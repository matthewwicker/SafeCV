# %%
# Define Model

import sys
sys.path.append('/usr/local/lib/python2.7/site-packages')
import os

from keras.layers import Dense, Dropout, Flatten, MaxPooling2D, Convolution2D
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
import keras
from keras.optimizers import Adam
import csv
import cv2
import matplotlib.pyplot as plt
import gc
from tqdm import trange
from random import shuffle
import numpy as np
from keras.utils.np_utils import to_categorical
NUM_CHANNELS = 3
IMAGE_WIDTH = 112 # Original: 455
IMAGE_HEIGHT = 112 # Original: 256
NUM_CLASSES = 3

def preprocess(img):
    size = (IMAGE_WIDTH,IMAGE_HEIGHT)
    resized = cv2.resize(img, size)
    return resized

def load_data(fdir, lfile):
    #print("LOADING DATA FROM: %s , %s"%(fdir,lfile))
    logs = []
    features = []
    labels = []
    with open(lfile,'rt') as f:
        reader = csv.reader(f)
        for line in reader:
            logs.append(line)
        log_labels = logs.pop(0)
    
    for i in trange(len(logs), desc="Loading Data"):
        img_path = logs[i][0]
        img = cv2.imread(fdir+img_path)
        features.append(preprocess(img))
        labels.append(float(logs[i][1]))
    return features, labels




model = Sequential([
                    Convolution2D(16, 3, 3, border_mode='same', subsample=(2, 2), input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, NUM_CLASSES), activation='relu'),
                    MaxPooling2D(pool_size=(3, 3)),
                    Dropout(0.2),
                    
                    Convolution2D(32, 3, 3, border_mode='same', activation='relu'),
                    MaxPooling2D(pool_size=(3, 3)),
                    Dropout(0.2),
                    
                    Convolution2D(64, 3, 3, border_mode='same', activation='relu'),
                    MaxPooling2D(pool_size=(2, 2)),
                    Dropout(0.2),
                    
                    Flatten(),
                    Dense(128, activation='tanh'),
                    Dropout(0.3),
                    Dense(NUM_CLASSES, activation='softmax'),
                    ])

model.load_weights('Nexar-Weights.model')

model.summary()
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:52: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(16, (3, 3), padding="same", strides=(2, 2), activation="relu", input_shape=(112, 112,...)`
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:56: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", activation="relu")`
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:60: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same", activation="relu")`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 56, 56, 16)        448
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 18, 18, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18, 18, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 18, 18, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 32)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 6, 64)          18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               73856
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 97,827
# Trainable params: 97,827
# Non-trainable params: 0
# _________________________________________________________________

# %%
features_directory = './data/'
labels_file = './data/labels.csv'

features, labels = load_data(features_directory, labels_file)

features = np.array(features).astype('float32')
labels = np.array(labels).astype('float32')



test_features = features
test_labels = labels
# Out:
# Loading Data: 100%|██████████| 11/11 [00:00<00:00, 160.83it/s]

# %%
from SafeCV_dev import *
img = test_features[10].astype('uint8')
cls = int(test_labels[10])

def red_manip(p, e):
    return [255, 0, 0]
def green_manip(p, e):
    return [0, 255, 0]

params_for_run = MCTS_Parameters(img, cls, model, predshape=(1,112,112,3))
params_for_run.verbose = True
params_for_run.simulations_cutoff = 100
params_for_run.backtracking_constant = 10
params_for_run.X_SHAPE = 112
params_for_run.Y_SHAPE = 112
params_for_run.verbose = True
params_for_run.VISIT_CONSTANT = 1
params_for_run.SIGMA_CONSTNAT = 1
params_for_run.simulations_cutoff = 100
params_for_run.target_class = 1
params_for_run.MANIP = green_manip

best_image, sev, prob, statistics = MCTS(params_for_run)
# Out:
# Exploring new keypoints on a new layer: 1 on node: 78
# Starting DFMCS. Cuttoff: -1
# Current Probability: 0.487617 Current Class: 1 Manipulations: 753
#
# Adversarial Example Found
# Current Probability: 0.482167 Current Class: 1 Manipulations: 754 Backtracking
# Backtracking Step L_0: 732 Probability: 0.499991 Class: 2, progress: 680/754
#  Done backtracking
# Back propogating and restarting search. Current Severity: 733
# Best severity: 733
# =================================================================
#
# Exploring new keypoints on an existing layer: 1 on node: 23
# Starting DFMCS. Cuttoff: 733
# Current Probability: 0.507135 Current Class: 1 Manipulations: 375
#
# Adversarial Example Found
# Current Probability: 0.494261 Current Class: 1 Manipulations: 376 Backtracking
# Backtracking Step L_0: 376 Probability: 0.666791 Class: 2, progress: 340/376
#  Done backtracking
# Back propogating and restarting search. Current Severity: 377
# Best severity: 377
# =================================================================
#
# manipulating and continuing the search: 23
# Exploring new keypoints on a new layer: 2 on node: 80
# Starting DFMCS. Cuttoff: 377
# Current Probability: 0.755576 Current Class: 2 Manipulations: 754  Back propogating and restarting search. Current Severity: -1
# Best severity: 377
# =================================================================
#
# Exploring new keypoints on an existing layer: 1 on node: 33
# Starting DFMCS. Cuttoff: 377
# Current Probability: 0.534534 Current Class: 1 Manipulations: 149
#
# Adversarial Example Found
# Current Probability: 0.62779 Current Class: 1 Manipulations: 150 Backtracking
# Backtracking Step L_0: 139 Probability: 0.909987 Class: 2, progress: 130/150
#  Done backtracking
# Back propogating and restarting search. Current Severity: 140
# Best severity: 140
# =================================================================
#
# Exploring new keypoints on an existing layer: 1 on node: 85
# Starting DFMCS. Cuttoff: 140
# Current Probability: 0.827916 Current Class: 2 Manipulations: 280  Back propogating and restarting search. Current Severity: -1
# Best severity: 140
# =================================================================
#
# Exploring new keypoints on an existing layer: 1 on node: 96
# Starting DFMCS. Cuttoff: 140
# Current Probability: 0.917583 Current Class: 2 Manipulations: 280  Back propogating and restarting search. Current Severity: -1
# Best severity: 140
# =================================================================
#
# Exploring new keypoints on an existing layer: 1 on node: 100
# Starting DFMCS. Cuttoff: 140
# Current Probability: 0.945645 Current Class: 2 Manipulations: 280  Back propogating and restarting search. Current Severity: -1
# Best severity: 140
# =================================================================
#
# Exploring new keypoints on an existing layer: 1 on node: 99
# Starting DFMCS. Cuttoff: 140
# Current Probability: 0.969756 Current Class: 2 Manipulations: 280  Back propogating and restarting search. Current Severity: -1
# Best severity: 140
# =================================================================
#
# Exploring new keypoints on an existing layer: 1 on node: 25
# Starting DFMCS. Cuttoff: 140
# Current Probability: 0.927627 Current Class: 2 Manipulations: 280  Back propogating and restarting search. Current Severity: -1
# Best severity: 140
# =================================================================
#
# Exploring new keypoints on an existing layer: 1 on node: 101
# Starting DFMCS. Cuttoff: 140
# Current Probability: 0.544163 Current Class: 2 Manipulations: 219
#
# Adversarial Example Found
# Current Probability: 0.522999 Current Class: 1 Manipulations: 220 Backtracking
# Backtracking Step L_0: 220 Probability: 0.63142 Class: 2, progress: 200/220
#  Done backtracking
# Back propogating and restarting search. Current Severity: 221
# Best severity: 140
# =================================================================
#
# Exploring new keypoints on an existing layer: 1 on node: 73
# Starting DFMCS. Cuttoff: 140
# Current Probability: 0.944564 Current Class: 2 Manipulations: 280  Back propogating and restarting search. Current Severity: -1
# Best severity: 140
# =================================================================
#
# Exploring new keypoints on an existing layer: 1 on node: 91
# Starting DFMCS. Cuttoff: 140
# Current Probability: 0.85779 Current Class: 2 Manipulations: 280   Back propogating and restarting search. Current Severity: -1
# Best severity: 140
# =================================================================
#
# Exploring new keypoints on an existing layer: 1 on node: 3
# Starting DFMCS. Cuttoff: 140
# Current Probability: 0.958556 Current Class: 2 Manipulations: 280  Back propogating and restarting search. Current Severity: -1
# Best severity: 140
# =================================================================
#
# Exploring new keypoints on an existing layer: 1 on node: 107
# Starting DFMCS. Cuttoff: 140
# Current Probability: 0.836134 Current Class: 2 Manipulations: 280  Back propogating and restarting search. Current Severity: -1
# Best severity: 140
# =================================================================
#
# manipulating and continuing the search: 23
# Exploring new keypoints on an existing layer: 2 on node: 55
# Starting DFMCS. Cuttoff: 140
# Current Probability: 0.856649 Current Class: 2 Manipulations: 280  Back propogating and restarting search. Current Severity: -1
# Best severity: 140
# =================================================================
#
# Exploring new keypoints on an existing layer: 1 on node: 38
# Starting DFMCS. Cuttoff: 140
# Current Probability: 0.989189 Current Class: 2 Manipulations: 280  Back propogating and restarting search. Current Severity: -1
# Best severity: 140
# =================================================================
#
# Exploring new keypoints on an existing layer: 1 on node: 55
# Starting DFMCS. Cuttoff: 140
# Current Probability: 0.885877 Current Class: 2 Manipulations: 280  Back propogating and restarting search. Current Severity: -1
# Best severity: 140
# =================================================================
#
# manipulating and continuing the search: 107
# Exploring new keypoints on an existing layer: 2 on node: 25
# Starting DFMCS. Cuttoff: 140
# Current Probability: 0.758172 Current Class: 2 Manipulations: 280  Back propogating and restarting search. Current Severity: -1
# Best severity: 140
# =================================================================
#
# Exploring new keypoints on an existing layer: 1 on node: 36
# Starting DFMCS. Cuttoff: 140
# Current Probability: 0.968826 Current Class: 2 Manipulations: 280  Back propogating and restarting search. Current Severity: -1
# Best severity: 140
# =================================================================
#
# Exploring new keypoints on an existing layer: 1 on node: 57
# Starting DFMCS. Cuttoff: 140
# Current Probability: 0.895169 Current Class: 2 Manipulations: 280  Back propogating and restarting search. Current Severity: -1
# Best severity: 140
# =================================================================
#
# manipulating and continuing the search: 3
# manipulating and continuing the search: 25
# Exploring new keypoints on a new layer: 3 on node: 49
# Starting DFMCS. Cuttoff: 140
# Current Probability: 0.909425 Current Class: 2 Manipulations: 280  Back propogating and restarting search. Current Severity: -1
# Best severity: 140
# =================================================================
#
# manipulating and continuing the search: 100
# Exploring new keypoints on an existing layer: 2 on node: 69
# Starting DFMCS. Cuttoff: 140
# Current Probability: 0.732038 Current Class: 2 Manipulations: 280  Back propogating and restarting search. Current Severity: -1
# Best severity: 140
# =================================================================
#
# Exploring new keypoints on an existing layer: 1 on node: 76
# Starting DFMCS. Cuttoff: 140
# Current Probability: 0.503824 Current Class: 1 Manipulations: 111
#
# Adversarial Example Found
# Current Probability: 0.517972 Current Class: 1 Manipulations: 112 Backtracking
# Backtracking Step L_0: 101 Probability: 0.793759 Class: 2, progress: 100/112
#  Done backtracking
# Back propogating and restarting search. Current Severity: 102
# Best severity: 102
# =================================================================
#
# Exploring new keypoints on an existing layer: 1 on node: 61
# Starting DFMCS. Cuttoff: 102
# Current Probability: 0.958485 Current Class: 2 Manipulations: 204  Back propogating and restarting search. Current Severity: -1
# Best severity: 102
# =================================================================
#
# manipulating and continuing the search: 107
# Exploring new keypoints on an existing layer: 2 on node: 46
# Starting DFMCS. Cuttoff: 102
# Current Probability: 0.918746 Current Class: 2 Manipulations: 98
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-e090b09ab654> in <module>()
#      21 params_for_run.MANIP = red_manip
#      22
# ---> 23 best_image, sev, prob, statistics = MCTS(params_for_run)
#
# /Users/matthewwicker/Desktop/gitrepos/SafeCV/Examples/Nexar-Example/SafeCV_dev/MCTS.pyc in MCTS(params)
#     351                 else:
#     352                     dparams = DFMCS_Parameters(params, IMAGE)
# --> 353                     adv, softmax, severity, kpd = DFMCS(dparams, cutoff=min_severity)
#     354                     if(severity != -1):
#     355                         severity += prior_severity
#
# /Users/matthewwicker/Desktop/gitrepos/SafeCV/Examples/Nexar-Example/SafeCV_dev/DFMCS.pyc in DFMCS(params, cutoff)
#     363         cutoff_enforced = True
#     364         for i in range(int(cutoff/int(1.5*params.VISIT_CONSTANT))):
# --> 365             params.r, image, params.TOTAL_PLAYS, params.MISCLASSIFIED = run_mcts_exploitation_step(params.model, image, params.TRUE_CLASS, params.kp, params.r, backprop, params.TOTAL_PLAYS)
#     366             if(params.MISCLASSIFIED):
#     367                 cutoff_enforced = False
#
# /Users/matthewwicker/Desktop/gitrepos/SafeCV/Examples/Nexar-Example/SafeCV_dev/DFMCS.pyc in run_mcts_exploitation_step(model, image, true_class, keypoints, keypoint_distribution, backpropogation, TOTAL_PLAYS, target_class)
#     248             expiter += 1
#     249
# --> 250         pred, prob = params.predict(image)
#     251         if((pred != int(true_class) and params.target_class == None) or (pred == target_class and params.target_class != None)):
#     252             if(params.verbose):
#
# /Users/matthewwicker/Desktop/gitrepos/SafeCV/Examples/Nexar-Example/SafeCV_dev/MCTS.pyc in predi(im)
#     156         def predi(im):
#     157             im_pred = self.preprocess(im)
# --> 158             prob = self.model.predict(im_pred, batch_size=1, verbose=0)
#     159             pred = np.argmax(np.asarray(prob))
#     160             return pred, prob
#
# /usr/local/lib/python2.7/site-packages/keras/models.pyc in predict(self, x, batch_size, verbose)
#     911         if not self.built:
#     912             self.build()
# --> 913         return self.model.predict(x, batch_size=batch_size, verbose=verbose)
#     914
#     915     def predict_on_batch(self, x):
#
# /usr/local/lib/python2.7/site-packages/keras/engine/training.pyc in predict(self, x, batch_size, verbose, steps)
#    1711         f = self.predict_function
#    1712         return self._predict_loop(f, ins, batch_size=batch_size,
# -> 1713                                   verbose=verbose, steps=steps)
#    1714
#    1715     def train_on_batch(self, x, y,
#
# /usr/local/lib/python2.7/site-packages/keras/engine/training.pyc in _predict_loop(self, f, ins, batch_size, verbose, steps)
#    1267                 else:
#    1268                     ins_batch = _slice_arrays(ins, batch_ids)
# -> 1269                 batch_outs = f(ins_batch)
#    1270                 if not isinstance(batch_outs, list):
#    1271                     batch_outs = [batch_outs]
#
# /usr/local/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2271         updated = session.run(self.outputs + [self.updates_op],
#    2272                               feed_dict=feed_dict,
# -> 2273                               **self.session_kwargs)
#    2274         return updated[:len(self.outputs)]
#    2275
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1061     feed_handles = {}
#    1062     if feed_dict:
# -> 1063       feed_dict = nest.flatten_dict_items(feed_dict)
#    1064       for feed, feed_val in feed_dict.items():
#    1065         for subfeed, subfeed_val in _feed_fn(feed, feed_val):
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/util/nest.pyc in flatten_dict_items(dictionary)
#     235   flat_dictionary = {}
#     236   for i, v in _six.iteritems(dictionary):
# --> 237     if not is_sequence(i):
#     238       if i in flat_dictionary:
#     239         raise ValueError(
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/util/nest.pyc in is_sequence(seq)
#     116     _warn_once("Sets are not currently considered sequences, but this may "
#     117                "change in the future, so consider avoiding using them.")
# --> 118   return (isinstance(seq, _collections.Sequence)
#     119           and not isinstance(seq, _six.string_types))
#     120
#
# /usr/local/Cellar/python/2.7.13_1/Frameworks/Python.framework/Versions/2.7/lib/python2.7/abc.pyc in __instancecheck__(cls, instance)
#     130         # Inline the cache checking when it's simple.
#     131         subclass = getattr(instance, '__class__', None)
# --> 132         if subclass is not None and subclass in cls._abc_cache:
#     133             return True
#     134         subtype = type(instance)
#
# /usr/local/Cellar/python/2.7.13_1/Frameworks/Python.framework/Versions/2.7/lib/python2.7/_weakrefset.pyc in __contains__(self, item)
#      70     def __contains__(self, item):
#      71         try:
# ---> 72             wr = ref(item)
#      73         except TypeError:
#      74             return False
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
print("BEST ADVERSARIAL EXAMPLE:")
plt.imshow(best_image)
plt.show()
prob = model.predict(best_image.reshape(1,112,112,3))
new_class = np.argmax(prob[0])
new_prob = prob[0][np.argmax(prob)]
print("True class: %s; Predicted as: %s with confidence: %s; After %s manipulations"%(cls, new_class, new_prob, sev ))
plt.clf()
print("MCTS Run analysis:")
a, = plt.plot(statistics[0], label="Min Severity Found")
b, = plt.plot(statistics[1], label="Severity per Iteration")
c, = plt.plot(statistics[2], label="Rolling Average Severity")
plt.legend(handles=[a,b,c], loc='center left', bbox_to_anchor=(1, 0.5))
plt.title("Single Run MCTS Statisitcs")
plt.xlabel("Iteration")
plt.ylabel("L_0 Severity")
plt.show()
# Out:
# BEST ADVERSARIAL EXAMPLE:
# True class: 0; Predicted as: 2 with confidence: 0.582714; After 3 manipulations
# MCTS Run analysis:
